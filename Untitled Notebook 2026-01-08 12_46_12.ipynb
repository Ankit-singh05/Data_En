# %%
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("CatalogExample")
    .getOrCreate()
)

# %%
# %sql
CREATE CATALOG IF NOT EXISTS demo_catalog

# %%
# %sql
USE CATALOG demo_catalog

# %%
# %sql
SELECT * FROM csv.'/Volumes/demo_catalog/default/pinki/orders_dataset.csv';

# %%
# %sql
CREATE TABLE IF NOT EXISTS demo_catalog.default.orders_dataset
USING CSV
LOCATION '/Volumes/demo_catalog/default/pinki/orders_dataset.csv'

# %%
# %sql
SELECT * FROM demo_catalog.default.orders_dataset

# %%
spark.sql("SHOW CATALOGS").show()

# %%
spark.sql("USE CATALOG demo_catalog")

# %%
spark.sql("SHOW SCHEMAS").show()

# %%
spark.sql("SHOW TABLES").show()

# %%
# Show catalogs
spark.sql("SHOW CATALOGS").show()

# Switch catalog
spark.sql("USE CATALOG demo_catalog")

# Show schemas
spark.sql("SHOW SCHEMAS").show()

# Use schema
spark.sql("USE demo_schema")

# Show tables
spark.sql("SHOW TABLES").show()

# %%
spark.sql("CREATE CATALOG IF NOT EXISTS demo_catalog")

# %%
spark.sql("USE CATALOG demo_catalog")

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS demo_schema")

# %%
spark.sql("USE demo_schema")

# %%
df = spark.read.option("header", True).csv(
    "/Volumes/demo_catalog/demo_schema/demo_volume/sellers_dataset.csv"
)

df.show()
df.display()

# %%
df_employees = spark.table("employees_from_volume")
display(df_employees)
